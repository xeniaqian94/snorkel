# %% [markdown]
# 1. Load purpose_regex_list and mechanism_regex_list
# 2. Regroup word-level labels into doc-level, remove the word labels when re.search(A_regex,segment) equals true
#
# 3. Create a annotations_word-level_all-to-date-2018-4-25.cue-removed.xlsx

# %%
from LF.util_purpose_default import common_regex_list,purpose_regex_list   # neg_LFs are reverse LFs for Background, Mechanism, Method, and Finding
from LF.util_mechanism_default import mechanism_regex_list
# from LF.util_background_default_categorical import background_LFs
# from LF.util_method_default_categorical import method_LFs
# from LF.util_finding_default_categorical import finding_LFs

print(purpose_regex_list)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# OperationalError: database is locked
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-5490d2fa1483> in <module>()
# ...
